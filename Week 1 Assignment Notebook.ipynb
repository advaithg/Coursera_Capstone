# %% [markdown]
# # Capstone Project Notebook
#
# <b> Description </b> <br>
# This notebook will be used for completing the Applied Data Science Capstone

# %%
#imports
import pandas as pd
import numpy as np

# %%
#print for assignment
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
